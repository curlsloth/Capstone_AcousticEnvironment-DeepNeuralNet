# %%
# https://users.iit.demokritos.gr/~tyianak/soundscape/
# https://github.com/tyiannak/soundscape_quality
import numpy as np
a = np.load('/Users/andrewchang/Springboard_GitHub/Capstone_AcousticEnv/data/raw/ATHUS/features/0000.npy')

# %%
type(a)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
plt.plot(a[0,:].T)
plt.show()
