# %% [markdown]
# This script may or may not work, as youtube is constantly making changes.

# %%
# https://github.com/alexmercerind/youtube-search-python
from youtubesearchpython import *
import pandas as pd

# citySearch = CustomSearch('city+soundscape+recording', VideoSortOrder.viewCount)
# natureSearch = CustomSearch('nature+soundscape+recording', VideoSortOrder.viewCount)
# citySearch = Search('city+soundscape+recording',limit = 100)

# %%
def getChanVideoList(channel_id):
    playlist = Playlist(playlist_from_channel_id(channel_id))

    print(f'Videos Retrieved: {len(playlist.videos)}')

    while playlist.hasMoreVideos:
        print('Getting more videos...')
        playlist.getNextVideos()
        print(f'Videos Retrieved: {len(playlist.videos)}')

    print('Found all the videos.')
    return pd.DataFrame(playlist.videos)

# %%
nature_df = getChanVideoList("UCjoFckSzE1jUM_kmtVHNlKg") # Nature Soundscapes
city_df = getChanVideoList("UCqRTj-Nu_8to3jIBlXptOtA") # Nomadic Ambience
# Out:
# Videos Retrieved: 100
# Getting more videos...
# Videos Retrieved: 200
# Getting more videos...
# Videos Retrieved: 300
# Getting more videos...
# Videos Retrieved: 400
# Getting more videos...
# Videos Retrieved: 434
# Found all the videos.
# Videos Retrieved: 100
# Getting more videos...
# Videos Retrieved: 200
# Getting more videos...
# Videos Retrieved: 211
# Found all the videos.

# %%
city_df.head()
# Out:
#             id                                         thumbnails  \
# 0  Yb1ss8JDLro  [{'url': 'https://i.ytimg.com/vi/Yb1ss8JDLro/h...
# 1  cystGDonEDA  [{'url': 'https://i.ytimg.com/vi/cystGDonEDA/h...
# 2  sQGOZ6VbSoU  [{'url': 'https://i.ytimg.com/vi/sQGOZ6VbSoU/h...
# 3  dAbeNCwA3xY  [{'url': 'https://i.ytimg.com/vi/dAbeNCwA3xY/h...
# 4  FntzXomEasg  [{'url': 'https://i.ytimg.com/vi/FntzXomEasg/h...
#
#                                                title  \
# 0  Lauterbrunnen, Switzerland Snowfall Walk, Rive...
# 1  Snowy Switzerland ❄️🌨☃️ Winter Walk: Stechelbe...
# 2  Soothing Ocean Sounds for Sleep Under Moonligh...
# 3  Snowfall Walk Zermatt, Switzerland 🇨🇭❄️ Relaxi...
# 4  Relaxing Snowy Wengen Village, Lauterbrunnen, ...
#
#                                              channel duration  \
# 0  {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...  1:18:17
# 1  {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...  1:02:46
# 2  {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...  2:00:22
# 3  {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...    40:06
# 4  {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...    38:08
#
#                                        accessibility  \
# 0  {'title': 'Lauterbrunnen, Switzerland Snowfall...
# 1  {'title': 'Snowy Switzerland ❄️🌨☃️ Winter Walk...
# 2  {'title': 'Soothing Ocean Sounds for Sleep Und...
# 3  {'title': 'Snowfall Walk Zermatt, Switzerland ...
# 4  {'title': 'Relaxing Snowy Wengen Village, Laut...
#
#                                                 link isPlayable
# 0  https://www.youtube.com/watch?v=Yb1ss8JDLro&li...       True
# 1  https://www.youtube.com/watch?v=cystGDonEDA&li...       True
# 2  https://www.youtube.com/watch?v=sQGOZ6VbSoU&li...       True
# 3  https://www.youtube.com/watch?v=dAbeNCwA3xY&li...       True
# 4  https://www.youtube.com/watch?v=FntzXomEasg&li...       True

# %%
city_df = city_df.loc[city_df['title'].str.contains('city', case=False)==True]
city_df.head()
# Out:
#              id                                         thumbnails  \
# 6   y-FNgD3QgPM  [{'url': 'https://i.ytimg.com/vi/y-FNgD3QgPM/h...
# 9   h3HaZ-MzP_Q  [{'url': 'https://i.ytimg.com/vi/h3HaZ-MzP_Q/h...
# 13  Q9DzUVFwFMM  [{'url': 'https://i.ytimg.com/vi/Q9DzUVFwFMM/h...
# 19  JY_olLeKs8E  [{'url': 'https://i.ytimg.com/vi/JY_olLeKs8E/h...
# 20  u4DEgkwv_vU  [{'url': 'https://i.ytimg.com/vi/u4DEgkwv_vU/h...
#
#                                                 title  \
# 6   Rainy, Windy, Snowy, Cold Walk in Times Square...
# 9   Snowfall in Zermatt Switzerland and Mattervisp...
# 13  Riomaggiore, Cinque Terre, Italy Sunset Ambien...
# 19  Walking Downtown Chicago, River Walk at Sunris...
# 20  Rainy Day Walk in Manhattan, New York, Binaura...
#
#                                               channel duration  \
# 6   {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...    51:18
# 9   {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...  1:07:27
# 13  {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...  3:00:16
# 19  {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...    40:32
# 20  {'name': 'Nomadic Ambience', 'id': 'UCqRTj-Nu_...    26:40
#
#                                         accessibility  \
# 6   {'title': 'Rainy, Windy, Snowy, Cold Walk in T...
# 9   {'title': 'Snowfall in Zermatt Switzerland and...
# 13  {'title': 'Riomaggiore, Cinque Terre, Italy Su...
# 19  {'title': 'Walking Downtown Chicago, River Wal...
# 20  {'title': 'Rainy Day Walk in Manhattan, New Yo...
#
#                                                  link isPlayable
# 6   https://www.youtube.com/watch?v=y-FNgD3QgPM&li...       True
# 9   https://www.youtube.com/watch?v=h3HaZ-MzP_Q&li...       True
# 13  https://www.youtube.com/watch?v=Q9DzUVFwFMM&li...       True
# 19  https://www.youtube.com/watch?v=JY_olLeKs8E&li...       True
# 20  https://www.youtube.com/watch?v=u4DEgkwv_vU&li...       True

# %%
playlist = Playlist('https://www.youtube.com/watch?v=ECSIkIC6RZw&list=PLkmb1BBi8y93qIwNcnuo3e9oyLxc8PVGB')

print(f'Videos Retrieved: {len(playlist.videos)}')

while playlist.hasMoreVideos:
    print('Getting more videos...')
    playlist.getNextVideos()
    print(f'Videos Retrieved: {len(playlist.videos)}')

print('Found all the videos.')
NomadicAmbience_nature_df = pd.DataFrame(playlist.videos)
# Out:
# Videos Retrieved: 34
# Found all the videos.

# %%
from datetime import datetime
DATE_FORMATS = ['%H:%M:%S', '%M:%S']
issues = set()
def parse(x_):
    for fmt in DATE_FORMATS:
        try:
            return datetime.strptime(x_, fmt).strftime('%H:%M:%S')
        except ValueError:
            pass
    issues.add(x_)


nature_df['duration_sec'] = pd.to_timedelta(nature_df['duration'].apply(lambda x: parse(x))).apply(lambda x: x.total_seconds())
city_df['duration_sec'] = pd.to_timedelta(city_df['duration'].apply(lambda x: parse(x))).apply(lambda x: x.total_seconds())
NomadicAmbience_nature_df['duration_sec'] = pd.to_timedelta(NomadicAmbience_nature_df['duration'].apply(lambda x: parse(x))).apply(lambda x: x.total_seconds())

# drop the videos < 120 seconds
nature_df = nature_df[nature_df['duration_sec']>120]
city_df = city_df[city_df['duration_sec']>120]
NomadicAmbience_nature_df = NomadicAmbience_nature_df[NomadicAmbience_nature_df['duration_sec']>120]

# %%
city_df.to_csv('../data/raw/youtube/NomadicAmbience_city.csv')
nature_df.to_csv('../data/raw/youtube/NatureSoundscapes.csv')
NomadicAmbience_nature_df.to_csv('../data/raw/youtube/NomadicAmbience_nature.csv')

# %% [markdown]
# # Download youtube as audio files

# %%
# https://github.com/ytdl-org/youtube-dl
# https://github.com/yt-dlp/yt-dlp

# from __future__ import unicode_literals
# import youtube_dl

from yt_dlp import YoutubeDL
from yt_dlp.utils import download_range_func

class MyLogger(object):
    def debug(self, msg):
        pass

    def warning(self, msg):
        pass

    def error(self, msg):
        print(msg)


def my_hook(d):
    if d['status'] == 'finished':
        print('Done downloading, now converting ...')


ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'm4a',
        'preferredquality': '192',
    }],
    'ffmpeg_location': '/Users/andrewchang/opt/anaconda3/envs/AcousticEnv/bin/ffmpeg',
    'logger': MyLogger(),
    'progress_hooks': [my_hook],
}
# with youtube_dl.YoutubeDL(ydl_opts) as ydl:
#     ydl.download(['https://www.youtube.com/watch?v=BaW_jenozKc'])

# %%
import warnings
warnings.filterwarnings("ignore")

ydl_opts['outtmpl'] = '/Users/andrewchang/Springboard_GitHub/Capstone_AcousticEnv/data/raw/youtube/NomadicAmbience_nature/%(id)s_%(start_time)i.m4a'

import random
random.seed(23)

with YoutubeDL(ydl_opts) as ydl:
    for index, row in NomadicAmbience_nature_df.iterrows():
        nRep = 0
        while nRep < 1: # number of segments within the same file
            dl_start_sec = random.randint(60,row['duration_sec']-15)
            ydl_opts['download_ranges'] = download_range_func(None, [(dl_start_sec,dl_start_sec+10)])
            ydl.download('https://www.youtube.com/embed/'+row['id']+'?start='+str(dl_start_sec))
            nRep += 1

# %%
ydl_opts['outtmpl'] = '/Users/andrewchang/Springboard_GitHub/Capstone_AcousticEnv/data/raw/youtube/NomadicAmbience_city/%(id)s_%(start_time)i.m4a'

import random
random.seed(23)

with YoutubeDL(ydl_opts) as ydl:
    for index, row in city_df.iloc[23:].iterrows():
        nRep = 0
        while nRep < 1: # number of segments within the same file
            dl_start_sec = random.randint(60,row['duration_sec']-15)
            ydl_opts['download_ranges'] = download_range_func(None, [(dl_start_sec,dl_start_sec+10)])
            ydl.download('https://www.youtube.com/embed/'+row['id']+'?start='+str(dl_start_sec))
            nRep += 1

# %%
ydl_opts['outtmpl'] = '/Users/andrewchang/Springboard_GitHub/Capstone_AcousticEnv/data/raw/youtube/NatureSoundscapes/%(id)s_%(start_time)i.m4a'

import random
random.seed(23)

with YoutubeDL(ydl_opts) as ydl:
    for index, row in nature_df.iterrows():
        nRep = 0
        while nRep < 1: # number of segments within the same file
            dl_start_sec = random.randint(60,row['duration_sec']-15)
            ydl_opts['download_ranges'] = download_range_func(None, [(dl_start_sec,dl_start_sec+10)])
            ydl.download('https://www.youtube.com/embed/'+row['id']+'?start='+str(dl_start_sec))
            nRep += 1
